# %%
import cv2
from collections import defaultdict
import supervision as sv
from ultralytics import YOLO
import math

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Set up video capture (input your video here)
cap = cv2.VideoCapture("/content/videoplayback.mp4")

# Line coordinates for counting
START_LINE = sv.Point(182, 254)
END_LINE = sv.Point(462, 254)

# Lane boundaries for lane detection (adjust as per your road setup)
LEFT_LANE_START = sv.Point(100, 254)
LEFT_LANE_END = sv.Point(300, 254)

RIGHT_LANE_START = sv.Point(320, 254)
RIGHT_LANE_END = sv.Point(520, 254)

# Dictionary to store vehicle history for tracking
track_history = defaultdict(lambda: [])
# Dictionary to track objects that have crossed the line
crossed_objects = {}
# Dictionary for lane changes
lane_changes = defaultdict(int)
# Dictionary for vehicle speeds
vehicle_speeds = {}
# Vehicle counts based on type (class)
vehicle_counts = defaultdict(int)

# Function to calculate speed (assuming frame rate and real-world scale)
def calculate_speed(x1, y1, x2, y2, fps, distance_scale):
    pixel_distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    speed = (pixel_distance / distance_scale) * fps * 3.6  # km/h
    return speed

# Open a video sink for output video
video_info = sv.VideoInfo.from_video_path("/content/videoplayback.mp4")
with sv.VideoSink("output_with_extra_features.mp4", video_info) as sink:

    fps = int(cap.get(cv2.CAP_PROP_FPS))  # Get FPS from the video
    distance_scale = 50  # Scale from pixels to real-world distance, adjust this

    while cap.isOpened():
        success, frame = cap.read()

        if success:
            # Run YOLOv8 tracking on the frame
            results = model.track(frame, classes=[2, 3, 5, 7], persist=True, save=True, tracker="bytetrack.yaml")

            # Get the bounding boxes and track IDs
            boxes = results[0].boxes.xywh.cpu()
            track_ids = results[0].boxes.id  # Check if track_ids exist

            # Only proceed if track_ids is not None
            if track_ids is not None:
                track_ids = track_ids.int().cpu().tolist()

                # Visualize the results on the frame
                annotated_frame = results[0].plot()
                detections = sv.Detections.from_ultralytics(results[0])

                # Process each tracked object
                for box, track_id in zip(boxes, track_ids):
                    x, y, w, h = box
                    track = track_history[track_id]
                    current_center = (float(x), float(y))
                    track.append(current_center)

                    # Keep only the last 30 tracks for smoothing
                    if len(track) > 30:
                        track.pop(0)

                    # Speed estimation: Check if there is enough history to calculate speed
                    if len(track) > 1:
                        prev_center = track[-2]
                        speed = calculate_speed(prev_center[0], prev_center[1], current_center[0], current_center[1], fps, distance_scale)
                        vehicle_speeds[track_id] = speed

                    # Check if the object crosses the counting line
                    if START_LINE.x < x < END_LINE.x and abs(y - START_LINE.y) < 5:
                        if track_id not in crossed_objects:
                            crossed_objects[track_id] = True
                            vehicle_type = results[0].names[results[0].boxes.cls.int().cpu().tolist()[0]]
                            vehicle_counts[vehicle_type] += 1
                            print(f"Vehicle {track_id} ({vehicle_type}) crossed the line")

                        # Color the box based on the vehicle type
                        color = (0, 255, 0) if vehicle_type == 'car' else (0, 0, 255) if vehicle_type == 'bus' else (255, 255, 0)
                        cv2.rectangle(annotated_frame, (int(x - w / 2), int(y - h / 2)), (int(x + w / 2), int(y + h / 2)), color, 2)

                    # Lane change detection
                    if LEFT_LANE_START.x < x < RIGHT_LANE_END.x:
                        if x < LEFT_LANE_END.x and lane_changes[track_id] == 0:
                            lane_changes[track_id] = 1  # Left lane
                            print(f"Vehicle {track_id} entered Left Lane")
                        elif x > RIGHT_LANE_START.x and lane_changes[track_id] == 1:
                            lane_changes[track_id] = 2  # Right lane (lane change detected)
                            print(f"Vehicle {track_id} changed to Right Lane")
                            cv2.putText(annotated_frame, f"Lane Change Detected: {track_id}", (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)

                    # Speed alert if the vehicle exceeds the speed limit (e.g., 80 km/h)
                    if track_id in vehicle_speeds and vehicle_speeds[track_id] > 80:
                        cv2.putText(annotated_frame, f"Speeding: {int(vehicle_speeds[track_id])} km/h", (int(x), int(y - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

                    # Draw the counting line and lanes on the frame
                    cv2.line(annotated_frame, (START_LINE.x, START_LINE.y), (END_LINE.x, END_LINE.y), (0, 255, 0), 2)
                    cv2.line(annotated_frame, (LEFT_LANE_START.x, LEFT_LANE_START.y), (LEFT_LANE_END.x, LEFT_LANE_END.y), (255, 0, 0), 2)
                    cv2.line(annotated_frame, (RIGHT_LANE_START.x, RIGHT_LANE_START.y), (RIGHT_LANE_END.x, RIGHT_LANE_END.y), (255, 0, 0), 2)

                # Display the count of different vehicle types on the frame
                count_text = f"Cars: {vehicle_counts['car']} Buses: {vehicle_counts['bus']} Trucks: {vehicle_counts['truck']}"
                cv2.putText(annotated_frame, count_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

                # Write the annotated frame to the output video
                sink.write_frame(annotated_frame)
        else:
            break

# Release the video capture
cap.release()
# Out:
# 0: 384x640 2 cars, 1 truck, 168.6ms
# Speed: 5.9ms preprocess, 168.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 1 truck, 182.6ms
# Speed: 5.9ms preprocess, 182.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 1 bus, 2 trucks, 153.2ms
# Speed: 3.8ms preprocess, 153.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 2 trucks, 153.5ms
# Speed: 3.8ms preprocess, 153.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 1 truck, 174.1ms
# Speed: 6.1ms preprocess, 174.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 2 trucks, 155.1ms
# Speed: 4.7ms preprocess, 155.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 1 truck, 170.6ms
# Speed: 4.9ms preprocess, 170.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 1 truck, 166.1ms
# Speed: 4.9ms preprocess, 166.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 2 trucks, 170.6ms
# Speed: 3.7ms preprocess, 170.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 1 truck, 172.5ms
# Speed: 4.5ms preprocess, 172.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 2 trucks, 149.3ms
# Speed: 4.0ms preprocess, 149.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 1 truck, 154.3ms
# Speed: 8.2ms preprocess, 154.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 1 truck, 170.3ms
# Speed: 3.7ms preprocess, 170.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 155.5ms
# Speed: 4.2ms preprocess, 155.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 140.5ms
# Speed: 3.6ms preprocess, 140.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 168.3ms
# Speed: 4.5ms preprocess, 168.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 149.7ms
# Speed: 3.8ms preprocess, 149.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 186.0ms
# Speed: 4.5ms preprocess, 186.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 159.0ms
# Speed: 3.6ms preprocess, 159.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 157.2ms
# Speed: 3.6ms preprocess, 157.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 167.3ms
# Speed: 4.5ms preprocess, 167.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 166.7ms
# Speed: 4.4ms preprocess, 166.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 167.6ms
# Speed: 4.1ms preprocess, 167.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 168.4ms
# Speed: 3.8ms preprocess, 168.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 157.3ms
# Speed: 3.7ms preprocess, 157.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 169.2ms
# Speed: 3.9ms preprocess, 169.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 157.6ms
# Speed: 4.9ms preprocess, 157.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 158.8ms
# Speed: 4.7ms preprocess, 158.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 168.7ms
# Speed: 4.7ms preprocess, 168.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 162.9ms
# Speed: 3.8ms preprocess, 162.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 155.2ms
# Speed: 3.8ms preprocess, 155.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 164.4ms
# Speed: 4.6ms preprocess, 164.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 170.0ms
# Speed: 4.1ms preprocess, 170.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 257.7ms
# Speed: 5.0ms preprocess, 257.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 232.9ms
# Speed: 4.0ms preprocess, 232.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 242.2ms
# Speed: 4.2ms preprocess, 242.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 229.1ms
# Speed: 4.1ms preprocess, 229.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 234.8ms
# Speed: 2.3ms preprocess, 234.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 241.2ms
# Speed: 4.6ms preprocess, 241.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 263.2ms
# Speed: 4.3ms preprocess, 263.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 251.5ms
# Speed: 4.5ms preprocess, 251.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 249.0ms
# Speed: 4.5ms preprocess, 249.0ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 255.2ms
# Speed: 4.0ms preprocess, 255.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 263.5ms
# Speed: 6.5ms preprocess, 263.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 252.7ms
# Speed: 3.8ms preprocess, 252.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 238.9ms
# Speed: 3.9ms preprocess, 238.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 164.3ms
# Speed: 4.0ms preprocess, 164.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 152.9ms
# Speed: 4.0ms preprocess, 152.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 177.3ms
# Speed: 4.1ms preprocess, 177.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 151.1ms
# Speed: 4.7ms preprocess, 151.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 154.8ms
# Speed: 3.5ms preprocess, 154.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 153.6ms
# Speed: 6.4ms preprocess, 153.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 153.0ms
# Speed: 3.5ms preprocess, 153.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 151.2ms
# Speed: 4.1ms preprocess, 151.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 174.8ms
# Speed: 3.8ms preprocess, 174.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 153.9ms
# Speed: 4.0ms preprocess, 153.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 160.6ms
# Speed: 4.5ms preprocess, 160.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 150.6ms
# Speed: 4.1ms preprocess, 150.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 153.6ms
# Speed: 3.9ms preprocess, 153.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 171.4ms
# Speed: 3.8ms preprocess, 171.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 176.4ms
# Speed: 5.7ms preprocess, 176.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 151.5ms
# Speed: 4.6ms preprocess, 151.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 151.5ms
# Speed: 3.7ms preprocess, 151.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 152.2ms
# Speed: 4.1ms preprocess, 152.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 161.3ms
# Speed: 4.3ms preprocess, 161.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 182.2ms
# Speed: 4.3ms preprocess, 182.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 154.8ms
# Speed: 3.8ms preprocess, 154.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 151.2ms
# Speed: 4.6ms preprocess, 151.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 153.4ms
# Speed: 3.5ms preprocess, 153.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 148.4ms
# Speed: 3.7ms preprocess, 148.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 150.4ms
# Speed: 3.9ms preprocess, 150.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 192.3ms
# Speed: 3.7ms preprocess, 192.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 154.3ms
# Speed: 3.8ms preprocess, 154.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 154.0ms
# Speed: 3.5ms preprocess, 154.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 152.3ms
# Speed: 4.0ms preprocess, 152.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 4.1ms preprocess, 149.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 187.5ms
# Speed: 4.6ms preprocess, 187.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 162.2ms
# Speed: 4.9ms preprocess, 162.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 147.4ms
# Speed: 3.8ms preprocess, 147.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 149.0ms
# Speed: 4.9ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 153.4ms
# Speed: 4.8ms preprocess, 153.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 150.9ms
# Speed: 4.0ms preprocess, 150.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 184.4ms
# Speed: 4.8ms preprocess, 184.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 151.9ms
# Speed: 2.1ms preprocess, 151.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 159.6ms
# Speed: 3.6ms preprocess, 159.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 154.6ms
# Speed: 4.7ms preprocess, 154.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 152.1ms
# Speed: 4.4ms preprocess, 152.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 172.8ms
# Speed: 3.9ms preprocess, 172.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 167.7ms
# Speed: 2.1ms preprocess, 167.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 154.0ms
# Speed: 4.0ms preprocess, 154.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 153.2ms
# Speed: 4.6ms preprocess, 153.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 151.0ms
# Speed: 3.6ms preprocess, 151.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 154.8ms
# Speed: 4.0ms preprocess, 154.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 180.5ms
# Speed: 3.9ms preprocess, 180.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 164.6ms
# Speed: 4.1ms preprocess, 164.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 152.4ms
# Speed: 4.7ms preprocess, 152.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 1 car, 157.7ms
# Speed: 3.9ms preprocess, 157.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 (no detections), 142.3ms
# Speed: 2.1ms preprocess, 142.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 164.2ms
# Speed: 3.9ms preprocess, 164.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 207.3ms
# Speed: 4.8ms preprocess, 207.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 148.5ms
# Speed: 4.8ms preprocess, 148.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 193.1ms
# Speed: 5.2ms preprocess, 193.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 237.5ms
# Speed: 4.6ms preprocess, 237.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 238.7ms
# Speed: 4.4ms preprocess, 238.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 243.9ms
# Speed: 4.3ms preprocess, 243.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 2 cars, 240.1ms
# Speed: 4.3ms preprocess, 240.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 230.0ms
# Speed: 4.2ms preprocess, 230.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 237.9ms
# Speed: 3.8ms preprocess, 237.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 251.1ms
# Speed: 3.9ms preprocess, 251.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 4 cars, 252.6ms
# Speed: 7.6ms preprocess, 252.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 4 cars, 255.6ms
# Speed: 4.6ms preprocess, 255.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 246.4ms
# Speed: 3.8ms preprocess, 246.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 261.2ms
# Speed: 5.7ms preprocess, 261.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 237.3ms
# Speed: 3.9ms preprocess, 237.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 3 cars, 219.5ms
# Speed: 4.7ms preprocess, 219.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 1 truck, 153.8ms
# Speed: 3.8ms preprocess, 153.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 1 truck, 196.2ms
# Speed: 5.4ms preprocess, 196.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640
0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 163.1ms
# Speed: 3.9ms preprocess, 163.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 151.9ms
# Speed: 4.4ms preprocess, 151.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 154.0ms
# Speed: 3.7ms preprocess, 154.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 158.9ms
# Speed: 3.6ms preprocess, 158.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 161.7ms
# Speed: 3.9ms preprocess, 161.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 164.0ms
# Speed: 4.1ms preprocess, 164.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 151.5ms
# Speed: 4.3ms preprocess, 151.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 155.4ms
# Speed: 4.1ms preprocess, 155.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 154.3ms
# Speed: 3.6ms preprocess, 154.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 169.4ms
# Speed: 4.3ms preprocess, 169.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 156.1ms
# Speed: 4.4ms preprocess, 156.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 150.0ms
# Speed: 4.4ms preprocess, 150.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 150.3ms
# Speed: 4.0ms preprocess, 150.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 161.7ms
# Speed: 4.3ms preprocess, 161.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 178.9ms
# Speed: 3.7ms preprocess, 178.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
# Vehicle 5 (car) crossed the line
#
# 0: 384x640 7 cars, 154.8ms
# Speed: 3.8ms preprocess, 154.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 162.9ms
# Speed: 4.1ms preprocess, 162.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 200.6ms
# Speed: 4.5ms preprocess, 200.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 234.5ms
# Speed: 4.3ms preprocess, 234.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
# Vehicle 4 (car) crossed the line
#
# 0: 384x640 7 cars, 243.9ms
# Speed: 7.0ms preprocess, 243.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 247.7ms
# Speed: 4.7ms preprocess, 247.7ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 243.2ms
# Speed: 4.0ms preprocess, 243.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 1 truck, 240.0ms
# Speed: 3.9ms preprocess, 240.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 7 cars, 240.7ms
# Speed: 3.9ms preprocess, 240.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 249.3ms
# Speed: 3.9ms preprocess, 249.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 1 truck, 253.9ms
# Speed: 3.8ms preprocess, 253.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 1 truck, 254.7ms
# Speed: 5.2ms preprocess, 254.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
# Vehicle 7 entered Left Lane
#
# 0: 384x640 5 cars, 1 truck, 265.6ms
# Speed: 3.9ms preprocess, 265.6ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 245.9ms
# Speed: 4.3ms preprocess, 245.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 241.0ms
# Speed: 4.8ms preprocess, 241.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 4 cars, 1 bus, 160.0ms
# Speed: 4.8ms preprocess, 160.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 150.8ms
# Speed: 3.7ms preprocess, 150.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 159.5ms
# Speed: 6.3ms preprocess, 159.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 149.9ms
# Speed: 4.3ms preprocess, 149.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 182.0ms
# Speed: 5.2ms preprocess, 182.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 159.3ms
# Speed: 5.2ms preprocess, 159.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 148.2ms
# Speed: 4.6ms preprocess, 148.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 155.6ms
# Speed: 3.7ms preprocess, 155.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 153.7ms
# Speed: 6.2ms preprocess, 153.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 171.8ms
# Speed: 4.1ms preprocess, 171.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 167.0ms
# Speed: 4.9ms preprocess, 167.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 154.4ms
# Speed: 4.8ms preprocess, 154.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 156.2ms
# Speed: 3.9ms preprocess, 156.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 169.1ms
# Speed: 3.6ms preprocess, 169.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 1 truck, 168.9ms
# Speed: 4.3ms preprocess, 168.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 4 cars, 2 trucks, 163.2ms
# Speed: 3.9ms preprocess, 163.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 157.7ms
# Speed: 4.0ms preprocess, 157.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 174.8ms
# Speed: 4.4ms preprocess, 174.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 4 cars, 2 trucks, 172.9ms
# Speed: 6.1ms preprocess, 172.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 172.6ms
# Speed: 3.9ms preprocess, 172.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 1 truck, 163.8ms
# Speed: 3.8ms preprocess, 163.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 1 truck, 160.9ms
# Speed: 4.0ms preprocess, 160.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 1 truck, 156.0ms
# Speed: 3.9ms preprocess, 156.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 172.6ms
# Speed: 4.9ms preprocess, 172.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
# Vehicle 9 (car) crossed the line
#
# 0: 384x640 6 cars, 164.9ms
# Speed: 4.2ms preprocess, 164.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 164.7ms
# Speed: 4.2ms preprocess, 164.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 156.4ms
# Speed: 4.9ms preprocess, 156.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 154.6ms
# Speed: 4.1ms preprocess, 154.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 156.9ms
# Speed: 5.0ms preprocess, 156.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 160.7ms
# Speed: 4.1ms preprocess, 160.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 180.3ms
# Speed: 4.2ms preprocess, 180.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 158.1ms
# Speed: 3.7ms preprocess, 158.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 154.2ms
# Speed: 3.8ms preprocess, 154.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 160.7ms
# Speed: 5.3ms preprocess, 160.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 163.1ms
# Speed: 4.1ms preprocess, 163.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 167.6ms
# Speed: 6.2ms preprocess, 167.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 162.5ms
# Speed: 3.8ms preprocess, 162.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 150.0ms
# Speed: 3.8ms preprocess, 150.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 150.0ms
# Speed: 3.9ms preprocess, 150.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
# Vehicle 7 (car) crossed the line
#
# 0: 384x640 6 cars, 167.1ms
# Speed: 5.2ms preprocess, 167.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 175.6ms
# Speed: 3.7ms preprocess, 175.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 158.1ms
# Speed: 4.0ms preprocess, 158.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 157.8ms
# Speed: 4.4ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 157.4ms
# Speed: 3.9ms preprocess, 157.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 152.6ms
# Speed: 4.4ms preprocess, 152.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 186.1ms
# Speed: 4.3ms preprocess, 186.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 5 cars, 163.7ms
# Speed: 4.1ms preprocess, 163.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 6 cars, 155.7ms
# Speed: 3.7ms preprocess, 155.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# ...
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 257.9ms
# Speed: 3.9ms preprocess, 257.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 238.0ms
# Speed: 5.7ms preprocess, 238.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 154.6ms
# Speed: 3.7ms preprocess, 154.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 182.8ms
# Speed: 3.8ms preprocess, 182.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 156.9ms
# Speed: 3.8ms preprocess, 156.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 160.0ms
# Speed: 4.1ms preprocess, 160.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 158.2ms
# Speed: 4.7ms preprocess, 158.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 159.5ms
# Speed: 3.0ms preprocess, 159.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 166.8ms
# Speed: 3.8ms preprocess, 166.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
# Vehicle 38 entered Left Lane
#
# 0: 384x640 9 cars, 180.2ms
# Speed: 6.6ms preprocess, 180.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 158.0ms
# Speed: 4.0ms preprocess, 158.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640
ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 236.9ms
# Speed: 3.9ms preprocess, 236.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 239.3ms
# Speed: 4.0ms preprocess, 239.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 256.0ms
# Speed: 4.1ms preprocess, 256.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 278.1ms
# Speed: 3.9ms preprocess, 278.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 268.7ms
# Speed: 4.6ms preprocess, 268.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 262.7ms
# Speed: 5.6ms preprocess, 262.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 257.9ms
# Speed: 3.8ms preprocess, 257.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 263.1ms
# Speed: 5.8ms preprocess, 263.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 10 cars, 167.4ms
# Speed: 4.7ms preprocess, 167.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 1 truck, 170.3ms
# Speed: 4.1ms preprocess, 170.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 158.4ms
# Speed: 3.9ms preprocess, 158.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 1 truck, 170.9ms
# Speed: 3.9ms preprocess, 170.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 163.2ms
# Speed: 4.2ms preprocess, 163.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 160.2ms
# Speed: 3.9ms preprocess, 160.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 161.0ms
# Speed: 4.3ms preprocess, 161.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 163.4ms
# Speed: 3.9ms preprocess, 163.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 171.6ms
# Speed: 5.9ms preprocess, 171.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 159.3ms
# Speed: 6.4ms preprocess, 159.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 156.9ms
# Speed: 4.6ms preprocess, 156.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 157.8ms
# Speed: 4.0ms preprocess, 157.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 168.4ms
# Speed: 3.9ms preprocess, 168.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 163.6ms
# Speed: 4.7ms preprocess, 163.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 167.1ms
# Speed: 4.3ms preprocess, 167.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 164.7ms
# Speed: 3.9ms preprocess, 164.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 160.4ms
# Speed: 3.9ms preprocess, 160.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 166.0ms
# Speed: 4.0ms preprocess, 166.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 164.8ms
# Speed: 3.9ms preprocess, 164.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 165.1ms
# Speed: 3.9ms preprocess, 165.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 158.5ms
# Speed: 3.9ms preprocess, 158.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 159.4ms
# Speed: 3.9ms preprocess, 159.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 170.1ms
# Speed: 3.8ms preprocess, 170.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 158.1ms
# Speed: 4.1ms preprocess, 158.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 170.6ms
# Speed: 4.2ms preprocess, 170.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 157.5ms
# Speed: 4.0ms preprocess, 157.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 162.6ms
# Speed: 3.6ms preprocess, 162.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 162.0ms
# Speed: 3.9ms preprocess, 162.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 160.2ms
# Speed: 4.0ms preprocess, 160.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 9 cars, 168.5ms
# Speed: 4.1ms preprocess, 168.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 164.9ms
# Speed: 3.8ms preprocess, 164.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 158.8ms
# Speed: 4.1ms preprocess, 158.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2
#
# 0: 384x640 8 cars, 159.0ms
# Speed: 4.3ms preprocess, 159.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track2

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.20-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.4.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.19.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.9-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.3.20-py3-none-any.whl (876 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 876.6/876.6 kB 13.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.9-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.20 ultralytics-thop-2.0.9
