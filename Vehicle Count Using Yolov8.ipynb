# %%
import cv2
from collections import defaultdict
import supervision as sv
from ultralytics import YOLO
import math

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')

# Set up video capture
cap = cv2.VideoCapture("/content/videoplayback.mp4")

# Line coordinates for counting
START_LINE = sv.Point(2, 254)
END_LINE = sv.Point(550, 254)

# Single combined lane boundary for lane detection
LANE_START = sv.Point(0, 254)
LANE_END = sv.Point(560, 254)

# Vehicle tracking and counting dictionaries
track_history = defaultdict(lambda: [])
crossed_objects = {}
lane_changes = defaultdict(int)
vehicle_speeds = {}
vehicle_counts = defaultdict(int)

# Function to calculate speed (assuming frame rate and real-world scale)
def calculate_speed(x1, y1, x2, y2, fps, distance_scale):
    pixel_distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)
    speed = (pixel_distance / distance_scale) * fps * 3.6  # km/h
    return speed

# Open a video sink for output video
video_info = sv.VideoInfo.from_video_path("/content/videoplayback.mp4")
with sv.VideoSink("output_with_single_lane_enhanced.mp4", video_info) as sink:

    fps = int(cap.get(cv2.CAP_PROP_FPS))  # Get FPS from the video
    distance_scale = 50  # Adjust this for real-world scale

    while cap.isOpened():
        success, frame = cap.read()
        if not success:
            break

        # Run YOLOv8 tracking on the frame
        results = model.track(frame, classes=[2, 3, 5, 7], persist=True, save=True, tracker="bytetrack.yaml")
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id

        if track_ids is not None:
            track_ids = track_ids.int().cpu().tolist()
            annotated_frame = results[0].plot()
            detections = sv.Detections.from_ultralytics(results[0])

            for box, track_id in zip(boxes, track_ids):
                x, y, w, h = box
                track = track_history[track_id]
                current_center = (float(x), float(y))
                track.append(current_center)

                # Keep only the last 30 tracks for smoothing
                if len(track) > 30:
                    track.pop(0)

                # Calculate speed if there is enough history
                if len(track) > 1:
                    prev_center = track[-2]
                    speed = calculate_speed(prev_center[0], prev_center[1], current_center[0], current_center[1], fps, distance_scale)
                    vehicle_speeds[track_id] = speed

                # Check if object crosses the counting line
                if START_LINE.x < x < END_LINE.x and abs(y - START_LINE.y) < 5:
                    if track_id not in crossed_objects:
                        crossed_objects[track_id] = True
                        vehicle_type = results[0].names[results[0].boxes.cls.int().cpu().tolist()[0]]
                        vehicle_counts[vehicle_type] += 1
                        print(f"Vehicle {track_id} ({vehicle_type}) crossed the line")

                    # Color the bounding box
                    color = (0, 255, 0) if vehicle_type == 'car' else (0, 0, 255) if vehicle_type == 'bus' else (255, 255, 0)
                    cv2.rectangle(annotated_frame, (int(x - w / 2), int(y - h / 2)), (int(x + w / 2), int(y + h / 2)), color, 2)

                # Lane change detection within the single large lane boundary
                if LANE_START.x < x < LANE_END.x:
                    if x < (LANE_START.x + LANE_END.x) / 2 and lane_changes[track_id] == 0:
                        lane_changes[track_id] = 1  # Left half of the lane
                        print(f"Vehicle {track_id} entered Left Half of Lane")
                    elif x > (LANE_START.x + LANE_END.x) / 2 and lane_changes[track_id] == 1:
                        lane_changes[track_id] = 2  # Right half of the lane (lane change detected)
                        print(f"Vehicle {track_id} changed to Right Half of Lane")
                        cv2.putText(annotated_frame, f"Lane Change: {track_id}", (int(x), int(y - 30)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

                # Speed alert if vehicle exceeds 80 km/h
                if track_id in vehicle_speeds and vehicle_speeds[track_id] > 80:
                    cv2.putText(annotated_frame, f"Speeding: {int(vehicle_speeds[track_id])} km/h", (int(x), int(y - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

                # Draw the counting line and single lane boundary on the frame
                cv2.line(annotated_frame, (START_LINE.x, START_LINE.y), (END_LINE.x, END_LINE.y), (0, 255, 0), 2)
                cv2.line(annotated_frame, (LANE_START.x, LANE_START.y), (LANE_END.x, LANE_END.y), (255, 0, 0), 2)

            # Display count of different vehicle types
            count_text = f"Cars: {vehicle_counts['car']} Buses: {vehicle_counts['bus']} Trucks: {vehicle_counts['truck']}"
            cv2.putText(annotated_frame, count_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)

            # Write the annotated frame to the output video
            sink.write_frame(annotated_frame)

# Release video capture
cap.release()
# Out:
# 0: 384x640 2 cars, 1 truck, 135.2ms
# Speed: 3.2ms preprocess, 135.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 1 truck, 135.8ms
# Speed: 3.1ms preprocess, 135.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 1 bus, 2 trucks, 135.6ms
# Speed: 4.5ms preprocess, 135.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 2 trucks, 130.9ms
# Speed: 4.3ms preprocess, 130.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 1 truck, 131.1ms
# Speed: 3.7ms preprocess, 131.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 2 trucks, 146.1ms
# Speed: 3.5ms preprocess, 146.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 1 truck, 156.2ms
# Speed: 3.7ms preprocess, 156.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 1 truck, 132.3ms
# Speed: 3.9ms preprocess, 132.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 2 trucks, 139.0ms
# Speed: 3.5ms preprocess, 139.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 1 truck, 137.0ms
# Speed: 4.2ms preprocess, 137.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 2 trucks, 134.3ms
# Speed: 3.7ms preprocess, 134.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 1 truck, 134.6ms
# Speed: 4.3ms preprocess, 134.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 1 truck, 158.4ms
# Speed: 4.1ms preprocess, 158.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 125.5ms
# Speed: 4.3ms preprocess, 125.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 133.6ms
# Speed: 3.3ms preprocess, 133.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 138.5ms
# Speed: 4.2ms preprocess, 138.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 138.1ms
# Speed: 3.3ms preprocess, 138.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 138.1ms
# Speed: 3.7ms preprocess, 138.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 173.3ms
# Speed: 3.4ms preprocess, 173.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 132.1ms
# Speed: 4.1ms preprocess, 132.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 140.5ms
# Speed: 3.6ms preprocess, 140.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 136.5ms
# Speed: 3.6ms preprocess, 136.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 135.5ms
# Speed: 3.6ms preprocess, 135.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 121.9ms
# Speed: 2.4ms preprocess, 121.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 161.2ms
# Speed: 4.1ms preprocess, 161.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 136.8ms
# Speed: 4.0ms preprocess, 136.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 133.8ms
# Speed: 3.5ms preprocess, 133.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 139.7ms
# Speed: 4.7ms preprocess, 139.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 135.7ms
# Speed: 3.5ms preprocess, 135.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 134.2ms
# Speed: 3.8ms preprocess, 134.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 179.6ms
# Speed: 3.6ms preprocess, 179.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 139.5ms
# Speed: 4.1ms preprocess, 139.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 133.7ms
# Speed: 3.2ms preprocess, 133.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 140.3ms
# Speed: 3.5ms preprocess, 140.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 2 (car) crossed the line
#
# 0: 384x640 1 car, 132.3ms
# Speed: 3.6ms preprocess, 132.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 135.9ms
# Speed: 3.9ms preprocess, 135.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 146.1ms
# Speed: 4.0ms preprocess, 146.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 222.2ms
# Speed: 5.2ms preprocess, 222.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 213.6ms
# Speed: 4.3ms preprocess, 213.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 206.7ms
# Speed: 3.7ms preprocess, 206.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 205.0ms
# Speed: 4.2ms preprocess, 205.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 232.8ms
# Speed: 4.8ms preprocess, 232.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 203.5ms
# Speed: 3.7ms preprocess, 203.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 212.7ms
# Speed: 3.6ms preprocess, 212.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 215.8ms
# Speed: 3.9ms preprocess, 215.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 230.4ms
# Speed: 3.7ms preprocess, 230.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 220.8ms
# Speed: 4.9ms preprocess, 220.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 215.3ms
# Speed: 4.7ms preprocess, 215.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 230.6ms
# Speed: 4.1ms preprocess, 230.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 232.2ms
# Speed: 3.8ms preprocess, 232.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 149.3ms
# Speed: 3.8ms preprocess, 149.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 135.4ms
# Speed: 4.0ms preprocess, 135.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 137.2ms
# Speed: 3.5ms preprocess, 137.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 134.4ms
# Speed: 3.4ms preprocess, 134.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 136.4ms
# Speed: 4.2ms preprocess, 136.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 163.1ms
# Speed: 4.1ms preprocess, 163.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 142.7ms
# Speed: 3.9ms preprocess, 142.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 136.2ms
# Speed: 4.2ms preprocess, 136.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 136.5ms
# Speed: 3.3ms preprocess, 136.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 137.7ms
# Speed: 3.6ms preprocess, 137.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 136.3ms
# Speed: 3.6ms preprocess, 136.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 155.9ms
# Speed: 4.6ms preprocess, 155.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 133.1ms
# Speed: 4.4ms preprocess, 133.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 143.3ms
# Speed: 4.5ms preprocess, 143.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 141.6ms
# Speed: 4.2ms preprocess, 141.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 134.6ms
# Speed: 3.6ms preprocess, 134.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 131.5ms
# Speed: 3.4ms preprocess, 131.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 148.3ms
# Speed: 4.3ms preprocess, 148.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 136.6ms
# Speed: 4.0ms preprocess, 136.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 143.7ms
# Speed: 3.6ms preprocess, 143.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 130.2ms
# Speed: 3.8ms preprocess, 130.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 130.3ms
# Speed: 4.1ms preprocess, 130.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 139.7ms
# Speed: 4.5ms preprocess, 139.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 131.8ms
# Speed: 4.3ms preprocess, 131.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 159.1ms
# Speed: 7.0ms preprocess, 159.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 133.0ms
# Speed: 3.5ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 136.9ms
# Speed: 6.5ms preprocess, 136.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 137.7ms
# Speed: 3.4ms preprocess, 137.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 132.3ms
# Speed: 3.9ms preprocess, 132.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 131.4ms
# Speed: 3.6ms preprocess, 131.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 154.0ms
# Speed: 4.7ms preprocess, 154.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 132.4ms
# Speed: 3.3ms preprocess, 132.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 143.3ms
# Speed: 4.0ms preprocess, 143.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 137.6ms
# Speed: 3.5ms preprocess, 137.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 130.2ms
# Speed: 4.1ms preprocess, 130.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 135.2ms
# Speed: 4.1ms preprocess, 135.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 149.4ms
# Speed: 4.2ms preprocess, 149.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 145.4ms
# Speed: 5.7ms preprocess, 145.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 134.8ms
# Speed: 3.4ms preprocess, 134.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 141.9ms
# Speed: 7.2ms preprocess, 141.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 135.2ms
# Speed: 4.2ms preprocess, 135.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 133.9ms
# Speed: 3.4ms preprocess, 133.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 136.5ms
# Speed: 3.6ms preprocess, 136.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 151.6ms
# Speed: 4.3ms preprocess, 151.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 134.1ms
# Speed: 4.4ms preprocess, 134.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 147.7ms
# Speed: 4.7ms preprocess, 147.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 1 car, 133.9ms
# Speed: 3.2ms preprocess, 133.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 (no detections), 132.4ms
# Speed: 5.0ms preprocess, 132.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 138.5ms
# Speed: 4.3ms preprocess, 138.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 158.3ms
# Speed: 4.2ms preprocess, 158.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 136.4ms
# Speed: 4.4ms preprocess, 136.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 138.0ms
# Speed: 3.6ms preprocess, 138.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 135.9ms
# Speed: 4.0ms preprocess, 135.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 133.3ms
# Speed: 3.6ms preprocess, 133.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 136.8ms
# Speed: 3.4ms preprocess, 136.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 2 cars, 154.1ms
# Speed: 4.0ms preprocess, 154.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 134.8ms
# Speed: 3.5ms preprocess, 134.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 142.2ms
# Speed: 3.7ms preprocess, 142.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 148.5ms
# Speed: 3.5ms preprocess, 148.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 4 cars, 133.7ms
# Speed: 4.1ms preprocess, 133.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 4 cars, 131.8ms
# Speed: 4.0ms preprocess, 131.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 154.7ms
# Speed: 4.1ms preprocess, 154.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 163.6ms
# Speed: 4.2ms preprocess, 163.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 211.6ms
# Speed: 4.3ms preprocess, 211.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 3 cars, 221.9ms
# Speed: 4.3ms preprocess, 221.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 1 truck, 211.7ms
# Speed: 6.3ms preprocess, 211.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 1 truck, 218.1ms
# Speed: 5.1ms preprocess, 218.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 1 truck, 200.0ms
# Speed: 4.5ms preprocess, 200.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 224.4ms
# Speed: 3.7ms preprocess, 224.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 210.2ms
# Speed: 3.8ms preprocess, 210.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640
3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 131.7ms
# Speed: 3.4ms preprocess, 131.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 155.7ms
# Speed: 3.6ms preprocess, 155.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 133.2ms
# Speed: 4.2ms preprocess, 133.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 142.6ms
# Speed: 6.7ms preprocess, 142.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 136.6ms
# Speed: 3.8ms preprocess, 136.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 122.2ms
# Speed: 2.4ms preprocess, 122.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 131.4ms
# Speed: 4.2ms preprocess, 131.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 164.0ms
# Speed: 3.9ms preprocess, 164.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 135.0ms
# Speed: 4.4ms preprocess, 135.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 146.0ms
# Speed: 4.1ms preprocess, 146.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 136.9ms
# Speed: 2.1ms preprocess, 136.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 137.7ms
# Speed: 4.5ms preprocess, 137.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 131.4ms
# Speed: 4.0ms preprocess, 131.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 160.8ms
# Speed: 3.6ms preprocess, 160.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 136.7ms
# Speed: 4.5ms preprocess, 136.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 150.4ms
# Speed: 3.7ms preprocess, 150.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 5 (car) crossed the line
#
# 0: 384x640 7 cars, 139.1ms
# Speed: 3.7ms preprocess, 139.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 135.1ms
# Speed: 4.4ms preprocess, 135.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 134.3ms
# Speed: 2.6ms preprocess, 134.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 156.5ms
# Speed: 4.5ms preprocess, 156.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 4 (car) crossed the line
#
# 0: 384x640 7 cars, 134.1ms
# Speed: 3.8ms preprocess, 134.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 144.8ms
# Speed: 4.8ms preprocess, 144.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 134.7ms
# Speed: 4.0ms preprocess, 134.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 1 truck, 138.0ms
# Speed: 3.7ms preprocess, 138.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 7 cars, 134.2ms
# Speed: 4.1ms preprocess, 134.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 155.0ms
# Speed: 4.3ms preprocess, 155.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 1 truck, 134.6ms
# Speed: 3.7ms preprocess, 134.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 1 truck, 150.4ms
# Speed: 4.3ms preprocess, 150.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 1 truck, 134.2ms
# Speed: 4.4ms preprocess, 134.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 137.1ms
# Speed: 5.1ms preprocess, 137.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 145.4ms
# Speed: 3.7ms preprocess, 145.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 4 cars, 1 bus, 139.1ms
# Speed: 6.0ms preprocess, 139.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 6 (car) crossed the line
#
# 0: 384x640 5 cars, 140.6ms
# Speed: 3.6ms preprocess, 140.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 144.3ms
# Speed: 4.0ms preprocess, 144.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 132.3ms
# Speed: 3.9ms preprocess, 132.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 134.2ms
# Speed: 3.9ms preprocess, 134.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 145.6ms
# Speed: 3.9ms preprocess, 145.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 136.8ms
# Speed: 4.3ms preprocess, 136.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 138.2ms
# Speed: 1.9ms preprocess, 138.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 145.3ms
# Speed: 4.7ms preprocess, 145.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 136.6ms
# Speed: 3.7ms preprocess, 136.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 135.6ms
# Speed: 4.0ms preprocess, 135.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 152.6ms
# Speed: 3.7ms preprocess, 152.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 141.2ms
# Speed: 4.7ms preprocess, 141.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 141.0ms
# Speed: 4.3ms preprocess, 141.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 1 truck, 143.8ms
# Speed: 3.8ms preprocess, 143.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 4 cars, 2 trucks, 132.9ms
# Speed: 2.2ms preprocess, 132.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 201.9ms
# Speed: 2.2ms preprocess, 201.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 213.7ms
# Speed: 4.2ms preprocess, 213.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 4 cars, 2 trucks, 202.7ms
# Speed: 4.9ms preprocess, 202.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 210.5ms
# Speed: 4.2ms preprocess, 210.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 1 truck, 206.9ms
# Speed: 4.3ms preprocess, 206.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 1 truck, 217.6ms
# Speed: 4.3ms preprocess, 217.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 1 truck, 208.1ms
# Speed: 4.3ms preprocess, 208.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 222.7ms
# Speed: 5.2ms preprocess, 222.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 9 (car) crossed the line
#
# 0: 384x640 6 cars, 226.8ms
# Speed: 3.7ms preprocess, 226.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 218.8ms
# Speed: 8.7ms preprocess, 218.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 223.1ms
# Speed: 3.7ms preprocess, 223.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 229.3ms
# Speed: 4.2ms preprocess, 229.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 209.1ms
# Speed: 4.7ms preprocess, 209.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 148.9ms
# Speed: 4.8ms preprocess, 148.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 137.7ms
# Speed: 3.9ms preprocess, 137.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 134.9ms
# Speed: 3.6ms preprocess, 134.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 146.2ms
# Speed: 4.2ms preprocess, 146.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 139.9ms
# Speed: 4.1ms preprocess, 139.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 141.8ms
# Speed: 4.0ms preprocess, 141.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 137.8ms
# Speed: 2.1ms preprocess, 137.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 133.5ms
# Speed: 3.8ms preprocess, 133.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 133.2ms
# Speed: 3.9ms preprocess, 133.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 147.8ms
# Speed: 4.1ms preprocess, 147.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 7 (car) crossed the line
#
# 0: 384x640 6 cars, 137.8ms
# Speed: 3.6ms preprocess, 137.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 145.7ms
# Speed: 5.0ms preprocess, 145.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 141.4ms
# Speed: 4.5ms preprocess, 141.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 123.9ms
# Speed: 2.5ms preprocess, 123.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 123.2ms
# Speed: 1.9ms preprocess, 123.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 120.4ms
# Speed: 2.0ms preprocess, 120.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 6 cars, 147.1ms
# Speed: 4.3ms preprocess, 147.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 5 cars, 139.9ms
# Speed: 5.7ms preprocess, 139.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# ...
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 205.6ms
# Speed: 4.1ms preprocess, 205.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 214.8ms
# Speed: 4.1ms preprocess, 214.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 218.8ms
# Speed: 4.3ms preprocess, 218.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 214.9ms
# Speed: 5.3ms preprocess, 214.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 233.5ms
# Speed: 4.3ms preprocess, 233.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 220.6ms
# Speed: 4.3ms preprocess, 220.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 222.3ms
# Speed: 4.7ms preprocess, 222.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 166.5ms
# Speed: 6.2ms preprocess, 166.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 136.8ms
# Speed: 3.9ms preprocess, 136.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640
4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 34 (car) crossed the line
# Vehicle 37 (car) crossed the line
#
# 0: 384x640 9 cars, 150.3ms
# Speed: 4.5ms preprocess, 150.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 144.8ms
# Speed: 4.1ms preprocess, 144.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 161.3ms
# Speed: 4.4ms preprocess, 161.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 210.4ms
# Speed: 8.7ms preprocess, 210.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 214.8ms
# Speed: 4.4ms preprocess, 214.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 220.1ms
# Speed: 4.5ms preprocess, 220.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 208.4ms
# Speed: 4.5ms preprocess, 208.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 205.6ms
# Speed: 4.2ms preprocess, 205.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 209.8ms
# Speed: 4.3ms preprocess, 209.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 10 cars, 209.7ms
# Speed: 6.1ms preprocess, 209.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 1 truck, 223.0ms
# Speed: 4.9ms preprocess, 223.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 217.1ms
# Speed: 4.3ms preprocess, 217.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 1 truck, 229.3ms
# Speed: 5.7ms preprocess, 229.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 226.5ms
# Speed: 4.3ms preprocess, 226.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 223.4ms
# Speed: 4.6ms preprocess, 223.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 213.6ms
# Speed: 6.3ms preprocess, 213.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 146.4ms
# Speed: 4.1ms preprocess, 146.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 138.9ms
# Speed: 5.0ms preprocess, 138.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 138.4ms
# Speed: 4.5ms preprocess, 138.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 38 (car) crossed the line
#
# 0: 384x640 9 cars, 136.2ms
# Speed: 4.2ms preprocess, 136.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 135.2ms
# Speed: 4.1ms preprocess, 135.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 133.9ms
# Speed: 4.8ms preprocess, 133.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 151.1ms
# Speed: 5.4ms preprocess, 151.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 143.1ms
# Speed: 5.6ms preprocess, 143.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 138.8ms
# Speed: 4.4ms preprocess, 138.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 39 entered Left Half of Lane
#
# 0: 384x640 9 cars, 134.8ms
# Speed: 3.8ms preprocess, 134.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 133.2ms
# Speed: 3.7ms preprocess, 133.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 132.1ms
# Speed: 3.6ms preprocess, 132.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 159.2ms
# Speed: 4.4ms preprocess, 159.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 133.0ms
# Speed: 4.8ms preprocess, 133.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 135.1ms
# Speed: 3.7ms preprocess, 135.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 139.9ms
# Speed: 3.7ms preprocess, 139.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 135.2ms
# Speed: 3.7ms preprocess, 135.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 136.2ms
# Speed: 4.3ms preprocess, 136.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
# Vehicle 36 (car) crossed the line
#
# 0: 384x640 9 cars, 166.3ms
# Speed: 4.1ms preprocess, 166.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 135.8ms
# Speed: 4.1ms preprocess, 135.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 137.6ms
# Speed: 4.2ms preprocess, 137.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 139.3ms
# Speed: 4.1ms preprocess, 139.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 9 cars, 126.7ms
# Speed: 1.9ms preprocess, 126.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 124.8ms
# Speed: 2.6ms preprocess, 124.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 159.7ms
# Speed: 2.7ms preprocess, 159.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
#
# 0: 384x640 8 cars, 125.2ms
# Speed: 2.0ms preprocess, 125.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/track3
